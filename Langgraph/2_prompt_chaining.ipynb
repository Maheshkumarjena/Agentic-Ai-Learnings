# %%
# %pip install -q langgraph langchain langchain-openai langchain-community
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langgraph.graph import StateGraph , START , END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv
import os
import certifi
from pydantic import BaseModel , Not

# %%
# LOADS ENVIRONMENT VARIABLES
os.environ["SSL_CERT_FILE"] = certifi.where()
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
# LLM 

# LLM 

llm = ChatOpenAI(
    model_name="gpt-3.5-turbo",
    temperature=0,
    openai_api_key=OPENAI_API_KEY
)

# %%
from langgraph.graph import StateGraph , START , END
from langchain_openai import ChatOpenAI
from typing import TypedDict, NotRequired
from dotenv import load_dotenv
import os
import certifi
from pydantic import BaseModel, Not

class BlogState(TypedDict):
    topic: str
    outline: NotRequired[str]
    structured_blog: NotRequired[str]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 class BlogState(TypedDict):
#       2     topic: str
#       3     outline: NotRequired[str]
#       4     structured_blog: NotRequired[str]
#
# Cell In[32], line 3, in BlogState()
#       1 class BlogState(TypedDict):
#       2     topic: str
# ----> 3     outline: NotRequired[str]
#       4     structured_blog: NotRequired[str]
#
# NameError: name 'NotRequired' is not defined

# %%
def create_outline(state: BlogState) -> BlogState:
    prompt = f"Create a detailed outline for a blog post about '{state['topic']}'."
    outline = model.invoke(prompt)
    state['outline'] = outline
    return state

# %%
graph = StateGraph(BlogState)
graph.add_node('create_outline' , create_outline) 
graph.add_node('create_structured_blog' , create_structured_blog)
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_structured_blog')
graph.add_edge('create_structured_blog', END)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 graph = StateGraph(BlogState)
#       2 graph.add_node('create_outline' , create_outline)
#       3 graph.add_node('create_structured_blog' , create_structured_blog)
#       4 graph.add_edge(START, 'create_outline')
#
# NameError: name 'BlogState' is not defined
